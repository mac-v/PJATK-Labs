# %% [markdown]
# # Task 1.

# %%
import pandas as pd

df = pd.read_csv('PAD_03_PD.csv', sep=";")
country_counts = df['Country'].value_counts()
country_counts
#df.groupby('Country').sum()
# Out:
# Country
# A    328
# B    201
# C    186
# D     78
# Name: count, dtype: int64

# %% [markdown]
# # Task 2

# %%
def count_goods(row):
    return row['owns_car'] + row['owns_TV'] + row['owns_house'] + row['owns_Phone']
    
df['owned_goods'] = df.apply(count_goods, axis=1)
df
# Out:
#       ID Country  owns_car  owns_TV  owns_house  owns_Phone gender  Age  \
# 0      1       A       0.0      0.0         0.0           1      M   61
# 1      2       B       0.0      0.0         0.0           1      M   44
# 2      3       A       0.0      0.0         0.0           1      M   56
# 3      4       A       0.0      0.0         0.0           1      M   53
# 4      5       C       1.0      1.0         0.0           1      K   60
# ..   ...     ...       ...      ...         ...         ...    ...  ...
# 795  796       B       0.0      0.0         0.0           1      K   28
# 796  797       B       0.0      0.0         0.0           1      M   26
# 797  798       A       0.0      0.0         0.0           1      M   61
# 798  799       B       0.0      1.0         0.0           1      K   47
# 799  800       B       0.0      1.0         0.0           1      K   51
#
#      owned_goods
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# ...

# %%
df['owned_goods'] = df[['owns_car', 'owns_TV', 'owns_house', 'owns_Phone']].sum(axis=1)
df
# Out:
#       ID Country  owns_car  owns_TV  owns_house  owns_Phone gender  Age  \
# 0      1       A       0.0      0.0         0.0           1      M   61
# 1      2       B       0.0      0.0         0.0           1      M   44
# 2      3       A       0.0      0.0         0.0           1      M   56
# 3      4       A       0.0      0.0         0.0           1      M   53
# 4      5       C       1.0      1.0         0.0           1      K   60
# ..   ...     ...       ...      ...         ...         ...    ...  ...
# 795  796       B       0.0      0.0         0.0           1      K   28
# 796  797       B       0.0      0.0         0.0           1      M   26
# 797  798       A       0.0      0.0         0.0           1      M   61
# 798  799       B       0.0      1.0         0.0           1      K   47
# 799  800       B       0.0      1.0         0.0           1      K   51
#
#      owned_goods
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# ...

# %% [markdown]
# # Task 3

# %%
df_gender_avg = df[['gender', 'owned_goods']].groupby('gender').mean().round(2).reset_index()
df_gender_avg
# Out:
#   gender  owned_goods
# 0      K         2.80
# 1      M         0.89

# %% [markdown]
# # Task 4

# %%
df = df[['Country', 'owned_goods','Age']].groupby('Country').agg(
    avg_goods=("owned_goods", "mean"),
    min_age=("Age", "min")
).round(2).reset_index()
df
# Out:
#   Country  avg_goods  min_age
# 0       A       0.86       18
# 1       B       1.46       18
# 2       C       3.03       18
# 3       D       4.00       18
